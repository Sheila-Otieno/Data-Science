# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import datetime as dt

# %%
air_1987 = pd.read_csv('1987.csv')
air_1987.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1987     10          14          3    741.0         730    912.0
# 1  1987     10          15          4    729.0         730    903.0
# 2  1987     10          17          6    741.0         730    918.0
# 3  1987     10          18          7    729.0         730    847.0
# 4  1987     10          19          1    749.0         730    922.0
#
#    CRSArrTime UniqueCarrier  FlightNum        ...          TaxiIn  TaxiOut  \
# 0         849            PS       1451        ...             NaN      NaN
# 1         849            PS       1451        ...             NaN      NaN
# 2         849            PS       1451        ...             NaN      NaN
# 3         849            PS       1451        ...             NaN      NaN
# 4         849            PS       1451        ...             NaN      NaN
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
air_1987.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum              float64
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance             float64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode     float64
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
air_1987.isnull().sum()
# Out:
# Year                       0
# Month                      0
# DayofMonth                 0
# DayOfWeek                  0
# DepTime                19685
# CRSDepTime                 0
# ArrTime                23500
# CRSArrTime                 0
# UniqueCarrier              0
# FlightNum                  0
# TailNum              1311826
# ActualElapsedTime      23500
# CRSElapsedTime             0
# AirTime              1311826
# ArrDelay               23500
# DepDelay               19685
# Origin                     0
# Dest                       0
# Distance                1015
# TaxiIn               1311826
# TaxiOut              1311826
# Cancelled                  0
# CancellationCode     1311826
# Diverted                   0
# CarrierDelay         1311826
# WeatherDelay         1311826
# NASDelay             1311826
# SecurityDelay        1311826
# LateAircraftDelay    1311826
# dtype: int64

# %%
air_1987_data = air_1987[['Year','Month','DayofMonth','DayOfWeek','DepTime','CRSDepTime','ArrTime','CRSArrTime','UniqueCarrier',
                         'FlightNum','ActualElapsedTime','CRSElapsedTime','ArrDelay','DepDelay','Origin','Dest','Distance',
                         'Cancelled','Diverted']]

# %%
air_1987_data.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1987     10          14          3    741.0         730    912.0
# 1  1987     10          15          4    729.0         730    903.0
# 2  1987     10          17          6    741.0         730    918.0
# 3  1987     10          18          7    729.0         730    847.0
# 4  1987     10          19          1    749.0         730    922.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ActualElapsedTime  CRSElapsedTime  \
# 0         849            PS       1451               91.0              79
# 1         849            PS       1451               94.0              79
# 2         849            PS       1451               97.0              79
# 3         849            PS       1451               78.0              79
# 4         849            PS       1451               93.0              79
#
#    ArrDelay  DepDelay Origin Dest  Distance  Cancelled  Diverted
# ...

# %%
air_1987_data.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#correlation matrix
air_1987_data_corr = air_1987_data.corr()
#column names
col = ['Year','Month','DayofMonth','DayOfWeek','DepTime','CRSDepTime','ArrTime','CRSArrTime','UniqueCarrier',
                         'FlightNum','ActualElapsedTime','CRSElapsedTime','ArrDelay','DepDelay','Origin','Dest','Distance',
                         'Cancelled','Diverted']  
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(air_1987_data_corr, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(col)
ax.set_yticklabels(col)
plt.show()

# %% [markdown]
# Read the 1997 dataset using pandas library

# %%
air_1997 = pd.read_csv('1997.csv')
air_1997.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1997      1          28          2   1615.0        1615   1728.0
# 1  1997      1          29          3   1624.0        1615   1735.0
# 2  1997      1          30          4   1626.0        1615   1730.0
# 3  1997      1          31          5   1628.0        1615   1729.0
# 4  1997      1          14          2   1503.0        1425   1619.0
#
#    CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 0        1725            WN       1159        ...              4        9
# 1        1725            WN       1159        ...              4       11
# 2        1725            WN       1159        ...              2       10
# 3        1725            WN       1159        ...              4        7
# 4        1535            WN       1221        ...              4        8
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
air_1997.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
air_1997_data = air_1997[['Year','Month','DayofMonth','DayOfWeek','DepTime','CRSDepTime','ArrTime','CRSArrTime','UniqueCarrier',
                         'FlightNum','ActualElapsedTime','CRSElapsedTime','ArrDelay','DepDelay','Origin','Dest','Distance',
                         'Cancelled','Diverted']]
air_1997_data.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1997      1          28          2   1615.0        1615   1728.0
# 1  1997      1          29          3   1624.0        1615   1735.0
# 2  1997      1          30          4   1626.0        1615   1730.0
# 3  1997      1          31          5   1628.0        1615   1729.0
# 4  1997      1          14          2   1503.0        1425   1619.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ActualElapsedTime  CRSElapsedTime  \
# 0        1725            WN       1159               73.0            70.0
# 1        1725            WN       1159               71.0            70.0
# 2        1725            WN       1159               64.0            70.0
# 3        1725            WN       1159               61.0            70.0
# 4        1535            WN       1221               76.0            70.0
#
#    ArrDelay  DepDelay Origin Dest  Distance  Cancelled  Diverted
# ...

# %%
#combining the year, month and dayofmonth column to create a date column 
air_1997_data['Date'] = air_1997_data['Year'].map(str) +'-'+ air_1997_data['Month'].map(str) +'-'+ air_1997_data['DayofMonth'].map(str)
air_1997_data['Date'].head(10)
air_1997_data.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1997      1          28          2   1615.0        1615   1728.0
# 1  1997      1          29          3   1624.0        1615   1735.0
# 2  1997      1          30          4   1626.0        1615   1730.0
# 3  1997      1          31          5   1628.0        1615   1729.0
# 4  1997      1          14          2   1503.0        1425   1619.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ActualElapsedTime  CRSElapsedTime  \
# 0        1725            WN       1159               73.0            70.0
# 1        1725            WN       1159               71.0            70.0
# 2        1725            WN       1159               64.0            70.0
# 3        1725            WN       1159               61.0            70.0
# 4        1535            WN       1221               76.0            70.0
#
#    ArrDelay  DepDelay Origin Dest  Distance  Cancelled  Diverted       Date
# ...

# %%
air_1997_data.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# Cancelled              int64
# Diverted               int64
# Date                  object
# dtype: object

# %%
air_1997_data['CRSArrTime'] = pd.to_datetime(air_1997_data['CRSArrTime'])
air_1997_data.dtypes
# Out:
# Year                          int64
# Month                         int64
# DayofMonth                    int64
# DayOfWeek                     int64
# DepTime                     float64
# CRSDepTime                    int64
# ArrTime                     float64
# CRSArrTime           datetime64[ns]
# UniqueCarrier                object
# FlightNum                     int64
# ActualElapsedTime           float64
# CRSElapsedTime              float64
# ArrDelay                    float64
# DepDelay                    float64
# Origin                       object
# Dest                         object
# Distance                      int64
# Cancelled                     int64
# Diverted                      int64
# Date                         object
# dtype: object

# %%
air_1997_data['Date']= pd.to_datetime(air_1997_data['Date'])
air_1997_data.dtypes
# Out:
# Year                          int64
# Month                         int64
# DayofMonth                    int64
# DayOfWeek                     int64
# DepTime                     float64
# CRSDepTime                    int64
# ArrTime                     float64
# CRSArrTime           datetime64[ns]
# UniqueCarrier                object
# FlightNum                     int64
# ActualElapsedTime           float64
# CRSElapsedTime              float64
# ArrDelay                    float64
# DepDelay                    float64
# Origin                       object
# Dest                         object
# Distance                      int64
# Cancelled                     int64
# Diverted                      int64
# Date                 datetime64[ns]
# dtype: object

# %%
air_1997_data['DepTime'] = air_1997_data['DepTime'].astype(str)
air_1997_data.dtypes
# Out:
# Year                          int64
# Month                         int64
# DayofMonth                    int64
# DayOfWeek                     int64
# DepTime                      object
# CRSDepTime                    int64
# ArrTime                     float64
# CRSArrTime           datetime64[ns]
# UniqueCarrier                object
# FlightNum                     int64
# ActualElapsedTime           float64
# CRSElapsedTime              float64
# ArrDelay                    float64
# DepDelay                    float64
# Origin                       object
# Dest                         object
# Distance                      int64
# Cancelled                     int64
# Diverted                      int64
# Date                 datetime64[ns]
# dtype: object

# %%
air_1997_data['DepTime'].head()
# Out:
# 0    1615.0
# 1    1624.0
# 2    1626.0
# 3    1628.0
# 4    1503.0
# Name: DepTime, dtype: object

# %%
air_1997_data['DepTime'] = air_1997_data['DepTime'].apply(lambda x: x.strip('.0'))
air_1997_data['DepTime'].head()
# Out:
# 0    1615
# 1    1624
# 2    1626
# 3    1628
# 4    1503
# Name: DepTime, dtype: object

# %%
air_1997_data['DepTime'] = air_1997_data['DepTime'].apply(lambda x: f'{x[:-2]}:{x[-2:]}')
air_1997_data['DepTime'].head()
# Out:
# 0    16:15
# 1    16:24
# 2    16:26
# 3    16:28
# 4    15:03
# Name: DepTime, dtype: object

# %%
air_1997_data['DepTime'].dropna()
# Out:
# 0          16:15
# 1          16:24
# 2          16:26
# 3          16:28
# 4          15:03
# 5          10:29
# 6           1:02
# 7          10:29
# 8           1:02
# 9           1:03
# 10          1:02
# 11         11:07
# 12          1:02
# 13          1:02
# 14          1:02
# 15         11:42
# 16          1:02
# 17         15:23
# 18         15:37
# 19         15:15
# 20         15:56
# 21          1:54
# 22          1:51
# 23          1:51
# 24          1:51
# 25          1:51
# 26          1:52
# 27         15:38
# 28         15:18
# 29          1:55
#            ...
# 5411813     7:03
# 5411814     7:09
# 5411815     7:03
# 5411816     7:02
# 5411817     6:58
# 5411818       :7
# 5411819     6:59
# 5411820     7:42
# 5411821     6:58
# 5411822     7:01
# 5411823     8:52
# 5411824     6:58
# 5411825      :75
# 5411826     7:08
# 5411827     6:59
# 5411828     6:59
# 5411829     6:58
# 5411830     6:58
# 5411831     6:57
# 5411832     6:59
# 5411833    13:34
# ...

# %%
air_1997_data.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek DepTime  CRSDepTime  ArrTime  \
# 0  1997      1          28          2   16:15        1615   1728.0
# 1  1997      1          29          3   16:24        1615   1735.0
# 2  1997      1          30          4   16:26        1615   1730.0
# 3  1997      1          31          5   16:28        1615   1729.0
# 4  1997      1          14          2   15:03        1425   1619.0
#
#                      CRSArrTime UniqueCarrier  FlightNum  ActualElapsedTime  \
# 0 1970-01-01 00:00:00.000001725            WN       1159               73.0
# 1 1970-01-01 00:00:00.000001725            WN       1159               71.0
# 2 1970-01-01 00:00:00.000001725            WN       1159               64.0
# 3 1970-01-01 00:00:00.000001725            WN       1159               61.0
# 4 1970-01-01 00:00:00.000001535            WN       1221               76.0
#
#    CRSElapsedTime  ArrDelay  DepDelay Origin Dest  Distance  Cancelled  \
# ...

# %%
air_1997_data.isnull().sum()
# Out:
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime              109844
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# ActualElapsedTime    109844
# CRSElapsedTime         4849
# ArrDelay             109844
# DepDelay              97763
# Origin                    0
# Dest                      0
# Distance                  0
# Cancelled                 0
# Diverted                  0
# Date                      0
# dtype: int64

# %%
air_1997_data['DepTime'] = air_1997_data['DepTime'].apply(lambda x: x.replace('n:an','0:00'))

# %%
air_1997_data['DepTime'] = air_1997_data['DepTime'].apply(lambda x: x.strip(':7'))

# %%
air_1997_data['DepTime'] = air_1997_data['DepTime'].apply(lambda x: x.strip(':75'))
